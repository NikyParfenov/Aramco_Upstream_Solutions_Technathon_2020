# %%
import cv2
import os
import pandas as pd
import numpy as np
import scipy.io
from PIL import Image
from matplotlib import pyplot as plt

# %%
os.listdir('r./data')
# Out:
# ['.ipynb_checkpoints',
#  'Beta_1_0.2.mat',
#  'Beta_1_0.5.mat',
#  'Beta_1_0.mat',
#  'Beta_2_0.2.mat',
#  'Beta_2_0.5.mat',
#  'Beta_2_0.mat',
#  'data_review.ipynb',
#  'Mono_1_0.2.mat',
#  'Mono_1_0.5.mat',
#  'Mono_1_0.mat',
#  'Mono_2_0.2.mat',
#  'Mono_2_0.5.mat',
#  'Mono_2_0.mat',
#  'Mono_3_0.2.mat',
#  'Mono_3_0.5.mat',
#  'Mono_3_0.mat',
#  'Normal_1_0.2.mat',
#  'Normal_1_0.5.mat',
#  'Normal_1_0.mat',
#  'Normal_2_0.2.mat',
#  'Normal_2_0.5.mat',
#  'Normal_2_0.mat',
#  'Normal_3_0.2.mat',
#  'Normal_3_0.5.mat',
#  'Normal_3_0.mat',
#  'Uniform_1_0.2.mat',
#  'Uniform_1_0.5.mat',
#  'Uniform_1_0.mat',
#  'Uniform_2_0.2.mat',
#  'Uniform_2_0.5.mat',
#  'Uniform_2_0.mat',
#  'Uniform_3_0.2.mat',
#  'Uniform_3_0.5.mat',
#  'Uniform_3_0.mat',
#  'VisualizeSlices.m',
#  'VisualizeSlicesHowTo.txt']

# %%
mat = scipy.io.loadmat('Beta_1_0.2.mat')
print(mat.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'bwImage', 'ctImage'])

# %%
mat['bwImage'].shape
# Out:
# (516, 516, 516)

# %%
mat['ctImage'].shape
# Out:
# (516, 516, 516)

# %%
plt.imshow(mat['ctImage'][:,:,0], cmap='Greys')
plt.show()
plt.imshow(mat['ctImage'][:,:,10], cmap='Greys')
plt.show()

# %%
plt.imshow(mat['bwImage'][:,:,0], cmap='Greys')
plt.show()
plt.imshow(mat['bwImage'][:,:,10], cmap='Greys')
plt.show()

# %%
mat_mono = scipy.io.loadmat('Mono_1_0.2.mat')
print(mat_mono.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'bwImage', 'ctImage'])
